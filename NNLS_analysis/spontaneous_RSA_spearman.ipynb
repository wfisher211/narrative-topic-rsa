# %%
import os, glob, re, csv
import numpy as np
import nibabel as nib
import statsmodels.api as sm
from nilearn.image import resample_to_img
import pandas as pd
from scipy.stats import ttest_1samp
from nilearn import plotting, datasets
import scipy.stats as stats
from scipy.stats import spearmanr

# %%
# Load the BOLD cleaned image
bold_img = nib.load('/Volumes/Passport/fmriprep/derivatives/pieMan_cleaned/sub-002/func/sub-002_task-pieman_run-1_cleaned_desc-masked_bold.nii.gz')

# Print voxel size (spatial resolution) and TR (temporal resolution)
zooms = bold_img.header.get_zooms()
print(f"Voxel size (mm): {zooms[:3]}")
print(f"TR (s): {zooms[3]}")
print(f"Shape {bold_img.shape}")
# Out:
# Voxel size (mm): (3.0, 3.0, 4.0)
# TR (s): 1.5
# Shape (65, 77, 49, 160)

# %%
# SET MAIN HYPERPARAMETERS
# TRAIT_LABEL = "Contemplating"  
ALL_TRAIT_LABELS = "spontaneous_cos"
ALL_TRAIT_SAVE_STRS = "spontaneous_cos"


#TRAIT_LABEL_SAVE_STRING = TRAIT_LABEL.replace(" ", "_").replace("-", "_")
STIMULUS_LABEL_SAVE_STRING = "pieman"

# %%
# ──────────────────────────────────────────────────────────────
# 0) PATHS & I/O
# ──────────────────────────────────────────────────────────────
root_dir  = "/Volumes/Passport/fmriprep"          # ←  same as in cleaning script
deriv_dir = os.path.join(root_dir, "derivatives") #   (don’t hard-code “subjects” yet)




# output from your behaviour-model RSA
rdm_path = os.path.join(
    deriv_dir, "spontaneous_cos_RDM",
    f"{STIMULUS_LABEL_SAVE_STRING}_{ALL_TRAIT_SAVE_STRS}_RDM.npy"
    )
model_rdm = np.load(rdm_path)

# %%
# ──────────────────────────────────────────────────────────────
# 1) SUBJECT / RUN FILTERS  (copy-paste verbatim)  ─────────────
# ──────────────────────────────────────────────────────────────
exclude_subs = {
    "sub-001","sub-021","sub-022","sub-038","sub-056","sub-068","sub-069"
}
exclude_sub_runs = {
    ("sub-002","2"),("sub-003","2"),("sub-004","2"),("sub-005","2"),("sub-006","2"),
    ("sub-008","2"),("sub-010","2"),("sub-011","2"),("sub-012","2"),("sub-013","2"),
    ("sub-014","2"),("sub-015","2"),("sub-016","2")
}
target_subject = None     # e.g. "sub-002" to run a single person

# %%
# ----------------------------------------------------------------
# 2)  BUILD SUBJECT LIST  (from cleaned derivatives)  ------------
# ----------------------------------------------------------------
cleaned_root = os.path.join(deriv_dir, f"{STIMULUS_LABEL_SAVE_STRING}_cleaned")
all_subs     = sorted(
    d for d in os.listdir(cleaned_root) if d.startswith("sub-")
)
if target_subject:
    if target_subject not in all_subs:
        raise ValueError(f"{target_subject} not found in {cleaned_root}")
    subjects = [target_subject]
else:
    subjects = [s for s in all_subs if s not in exclude_subs]

print("Subjects to process →", ", ".join(subjects))
# Out:
# Subjects to process → sub-002, sub-003, sub-004, sub-005, sub-006, sub-007, sub-008, sub-009, sub-010, sub-011, sub-012, sub-013, sub-014, sub-015, sub-016, sub-017, sub-018, sub-019, sub-020, sub-023, sub-024, sub-025, sub-026, sub-027, sub-028, sub-029, sub-030, sub-031, sub-032, sub-033, sub-034, sub-035, sub-036, sub-037, sub-039, sub-040, sub-041, sub-042, sub-043, sub-044, sub-045, sub-046, sub-047, sub-048, sub-049, sub-050, sub-051, sub-052, sub-053, sub-054, sub-055, sub-057, sub-058, sub-059, sub-060, sub-061, sub-062, sub-063, sub-064, sub-065, sub-066, sub-067, sub-070, sub-071, sub-072, sub-073, sub-074, sub-075, sub-076, sub-077, sub-078, sub-079, sub-080, sub-081, sub-082

# %%
# ──────────────────────────────────────────────────────────────
# 3) FETCH SCHAEFER ATLAS  ─────────────────────────────────────
# ──────────────────────────────────────────────────────────────

# Schaefer parcel/atlas parameters
n_rois = 200
yeo_networks = 17
resolution_mm = 2                   # resolution of your Schaefer atlas (double check!)

schaefer    = datasets.fetch_atlas_schaefer_2018(
                 n_rois=n_rois,
                 yeo_networks=yeo_networks,
                 resolution_mm=resolution_mm
             )
atlas_img   = nib.load(schaefer['maps'])  # default 2mm MNI - but our images 3x3x4 (Pieman and others) OR 2.5^3 (ie., Black and Forgot)

atlas_resampled = resample_to_img(atlas_img, bold_img, interpolation='nearest')
atlas_data     = atlas_resampled.get_fdata()



# Change Schaeffer Labels so 0 is whole brain and 1 corresponds to 1st ROI
labels = schaefer['labels']
# change to string and remove excess
labels = [l.replace(b'17Networks_', b'').decode('utf-8') for l in labels]
# Prepend background label
labels = np.insert(labels, 0, "Background")

# %%
# ──────────────────────────────────────────────────────────────
# 4) Define Spearman‐RSA function  ─────────────────────────────
# ──────────────────────────────────────────────────────────────


def rsa_spearman(neural_rdm: np.ndarray, model_rdm: np.ndarray):
    """
    Spearman‐based RSA.
    Returns
    -------
    rho  : float   – Spearman correlation between the lower triangles
    pval : float   – two‐tailed p‐value for that Spearman rho
    """
    # (Assumes both RDMs are square, same shape, e.g. (160, 160).)
    assert neural_rdm.shape == model_rdm.shape, f"RDMs must be the same shape, shapes are {neural_rdm.shape} and {model_rdm.shape}"

    i_low = np.tril_indices(neural_rdm.shape[0], k=-1)
    y = neural_rdm[i_low]    # neural dissimilarities
    x = model_rdm[i_low]     # model dissimilarities

    # compute Spearman correlation
    rho, pval = spearmanr(x, y)
    return float(rho), float(pval)
    

# ──────────────────────────────────────────────────────────────
# 5) Single Trait per-subject function  (adds run-skip check)  ─────────
# ──────────────────────────────────────────────────────────────
def run_parcel_rsa_for_subject(sub: str,
        trait_save: str,
        model_rdm: np.ndarray):
    func_dir   = os.path.join(cleaned_root, sub, "func")
    run_pat    = os.path.join(func_dir,
                  f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_run-*_*cleaned_desc-masked_bold.nii.gz")
    single_pat = os.path.join(func_dir,
                  f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_cleaned_desc-masked_bold.nii.gz")
    bold_files = sorted(glob.glob(run_pat)) + sorted(glob.glob(single_pat))
    if not bold_files:
        print(f"⏩ {sub}: no cleaned runs")
        return

    rows = []
    for bf in bold_files:
        m   = re.search(r"_run-(\d+)_", os.path.basename(bf))
        run = m.group(1) if m else None
        if run and (sub, run) in exclude_sub_runs:
            print(f"   • skipping {sub} run-{run} (in exclusion list)")
            continue

        bold_img  = nib.load(bf)
        bold_data = bold_img.get_fdata()

        atlas_resampled = resample_to_img(atlas_img, bold_img, interpolation="nearest")
        atlas_data      = atlas_resampled.get_fdata()

        for parcel_id in range(1, n_rois + 1):
            mask = atlas_data == parcel_id
            if not mask.any(): continue

            #compute neural rdm
            rdm   = 1 - np.corrcoef(bold_data[mask, :].T).astype(np.float32)

            # Compute Spearman RSA
            rho, pval = rsa_spearman(rdm, model_rdm)
            parcel_label = labels[parcel_id]
            rows.append([sub, run or "NA", parcel_id, parcel_label, rho, pval])
            
    # ---- write one CSV per subject ----
    out_dir  = os.path.join(deriv_dir, "RSA_stats")

    # add the stimulus‐specific subfolder (e.g. "pieman")
    stim_folder = os.path.join(out_dir, STIMULUS_LABEL_SAVE_STRING)
    os.makedirs(stim_folder, exist_ok=True)

    # add the trait‐specific subfolder (e.g. "feeling_Affectionate")
    trait_folder = os.path.join(stim_folder, trait_save)
    os.makedirs(trait_folder, exist_ok=True)

    out_csv = os.path.join(trait_folder, f"{sub}_{STIMULUS_LABEL_SAVE_STRING}_{trait_save}_parcel_RSA_spearman.csv")
    with open(out_csv, "w", newline="") as f:
        csv.writer(f).writerows([["subject","run","parcel_num","parcel_label","rho", "pval"]] + rows)
    print(f"✅ {sub}: {len(rows)} rows → {out_csv}")

# %%
# ----------------------------------------------------------------------
# 6. CALL FUNCTION FOR EACH SUBJECT
# ----------------------------------------------------------------------


print(f"\n── TRAIT: {ALL_TRAIT_SAVE_STRS} ──")

# 1) load that trait's behavioural RDM once
# rdm already loaded as model_rdm

# 2) run every subject for this trait
for sub in subjects:
    run_parcel_rsa_for_subject(sub, ALL_TRAIT_SAVE_STRS, model_rdm)

        
print("\nALL DONE 🎉")
# Out:
# ── TRAIT: spontaneous_cos ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-002_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-003_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-004_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-005_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-006_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-007_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-008_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-009_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-010_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-011_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-012_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-013_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-014_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-015_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-016_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-017_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-018_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-019_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-020_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-023_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-024_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-025_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-026_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-027_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-028_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-029_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-030_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-031_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-032_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-033_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-034_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-035_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-036_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-037_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-039_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-040_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-041_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-042_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-043_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-044_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-045_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-046_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-047_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-048_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-049_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-050_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-051_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-052_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-053_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-054_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-055_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-057_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-058_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-059_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-060_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-061_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-062_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-063_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-064_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-065_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-066_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-067_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-070_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-071_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-072_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-073_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-074_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-075_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-076_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-077_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-078_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-079_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-080_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-081_pieman_spontaneous_cos_parcel_RSA_spearman.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/sub-082_pieman_spontaneous_cos_parcel_RSA_spearman.csv
#
# ALL DONE 🎉

# %%
# ------------------------------------------------------------------
# 0) helper: run parcel-wise t-tests for ONE trait and save summary
# ------------------------------------------------------------------
def run_group_stats_for_trait(stim_label: str,
                              trait_save: str,
                              trait_long: str,
                              subjects: list[str],
                              n_rois: int):

    # (1) gather all subject files for this trait
    dfs = []
    for sub in subjects:
        filepath = os.path.join(
            deriv_dir, "RSA_stats", stim_label, trait_save,
            f"{sub}_{stim_label}_{trait_save}_parcel_RSA_spearman.csv"   
        )
        dfs.append(pd.read_csv(filepath))
    all_df = pd.concat(dfs, ignore_index=True)
    

    # (2) sanity check
    n_sub = all_df["subject"].nunique()
    print(f"{trait_long}: concatenated {n_sub} subjects")

    #fisher z transform the rho - values
    all_df["rho_z"] = np.arctanh(all_df["rho"])  # Fisher z-transform
    


    # (3) parcel-wise one-sample t-tests
    t_vals, p_vals = [], []
    for parcel in range(1, n_rois + 1):
        parcel_df = all_df[all_df["parcel_num"] == parcel]
        assert len(parcel_df) == n_sub, \
            f"Parcel {parcel}: expected {n_sub} rows, got {len(parcel_df)}"
        t, p = ttest_1samp(parcel_df["rho_z"], 0, alternative="greater")
        t_vals.append(t); p_vals.append(p)

    # (4) summary dataframe
    summary = pd.DataFrame({
        "parcel_num" : np.arange(1, n_rois + 1),
        "parcel_label": labels[1:],       # skip background
        "t_value"    : t_vals,
        "p_value"    : p_vals
    })
    summary = summary.sort_values("parcel_num")      # ← NEW
    summary["parcel_label"] = labels[1:]    # ← NEW
    
    # (5) save
    out_dir = os.path.join(
        deriv_dir, "RSA_stats", stim_label, trait_save
    )
    os.makedirs(out_dir, exist_ok=True)
    out_csv = os.path.join(
        out_dir, f"group_stats_{stim_label}_{trait_save}_spearman.csv"
    )
    summary.to_csv(out_csv, index=False)
    print(f"✅ Saved group stats for {trait_long} → {out_csv}\n")

# %%
# ------------------------------------------------------------------
# 1) DRIVER LOOP  (iterate over all 13 traits)
# ------------------------------------------------------------------

run_group_stats_for_trait(
    STIMULUS_LABEL_SAVE_STRING,
    ALL_TRAIT_SAVE_STRS,
    ALL_TRAIT_SAVE_STRS,
    subjects,
    n_rois
)
# Out:
# spontaneous_cos: concatenated 75 subjects
# ✅ Saved group stats for spontaneous_cos → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/group_stats_pieman_spontaneous_cos_spearman.csv

# %%
import nibabel as nib
import numpy as np
from nilearn.image import resample_to_img

# atlases you already loaded
atlas_res = resample_to_img(atlas_img, bold_img, interpolation="nearest")
atlas_data = atlas_res.get_fdata()

mask_out_dir = os.path.join(
    deriv_dir, "RSA_stats", STIMULUS_LABEL_SAVE_STRING, ALL_TRAIT_SAVE_STRS)

parcel_id = 140            # pick any ID you want to sanity-check
mask      = (atlas_data == parcel_id).astype(np.uint8)

mask_img = nib.Nifti1Image(mask, atlas_res.affine, atlas_res.header)
outfile = os.path.join(mask_out_dir, f"parcel_{parcel_id}_mask.nii.gz")
nib.save(mask_img, outfile)
print(f"mask saved → {outfile}")
# Out:
# mask saved → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/spontaneous_cos/parcel_140_mask.nii.gz
