# %%
import os, glob, re, csv
import numpy as np
import nibabel as nib
import statsmodels.api as sm
from nilearn import datasets
from nilearn.image import resample_to_img
import pandas as pd
from scipy.stats import ttest_1samp
from nilearn import plotting, datasets
import scipy.stats as stats
from scipy.optimize import nnls   
from statsmodels.stats.multitest import fdrcorrection

# %%
# Load the BOLD cleaned image
bold_img = nib.load('/Volumes/Passport/fmriprep/derivatives/pieMan_cleaned/sub-002/func/sub-002_task-pieman_run-1_cleaned_desc-masked_bold.nii.gz')

# Print voxel size (spatial resolution) and TR (temporal resolution)
zooms = bold_img.header.get_zooms()
print(f"Voxel size (mm): {zooms[:3]}")
print(f"TR (s): {zooms[3]}")
print(f"Shape {bold_img.shape}")
# Out:
# Voxel size (mm): (3.0, 3.0, 4.0)
# TR (s): 1.0
# Shape (65, 77, 49, 160)

# %%
# SET MAIN HYPERPARAMETERS
# TRAIT_LABEL = "Contemplating"  
ALL_TRAIT_LABELS = [
    "Open-minded","feeling Affectionate","Attentive","Assertive",
    "feeling Gloomy","feeling Peaceful","Agreeable","Judging",
    "feeling Angry","feeling Bewildered","Impulsive",
    "Self-disciplined","Contemplating"
]
ALL_TRAIT_SAVE_STRS = [t.replace(" ","_").replace("-","_")
                       for t in ALL_TRAIT_LABELS]
# Our 13 trait labels 
# ["Open-minded", "feeling Affectionate", "Attentive", "Assertive", "feeling Gloomy", "feeling Peaceful", "Agreeable", "Judging", "feeling Angry", "feeling Bewildered", "Impulsive", "Self-disciplined", "Contemplating"]

#TRAIT_LABEL_SAVE_STRING = TRAIT_LABEL.replace(" ", "_").replace("-", "_")
STIMULUS_LABEL_SAVE_STRING = "pieman"

# %%
# ──────────────────────────────────────────────────────────────
# 0) PATHS & I/O
# ──────────────────────────────────────────────────────────────
root_dir  = "/Volumes/Passport/fmriprep"          # ←  same as in cleaning script
deriv_dir = os.path.join(root_dir, "derivatives") #   (don’t hard-code “subjects” yet)



# output from your behaviour-model RSA
for trait_long, trait_save in zip(ALL_TRAIT_LABELS, ALL_TRAIT_SAVE_STRS):
    rdm_path = os.path.join(
        deriv_dir, "RDMs_behavior",
        f"{STIMULUS_LABEL_SAVE_STRING}_{trait_save}_RDM.npy"
    )
    model_rdm = np.load(rdm_path)

# %%
# ──────────────────────────────────────────────────────────────
# 1) SUBJECT / RUN FILTERS  (copy-paste verbatim)  ─────────────
# ──────────────────────────────────────────────────────────────
exclude_subs = {
    "sub-001","sub-021","sub-022","sub-038","sub-056","sub-068","sub-069"
}
exclude_sub_runs = {
    ("sub-002","2"),("sub-003","2"),("sub-004","2"),("sub-005","2"),("sub-006","2"),
    ("sub-008","2"),("sub-010","2"),("sub-011","2"),("sub-012","2"),("sub-013","2"),
    ("sub-014","2"),("sub-015","2"),("sub-016","2")
}
target_subject = None     # e.g. "sub-002" to run a single person

# %%
# ----------------------------------------------------------------
# 2)  BUILD SUBJECT LIST  (from cleaned derivatives)  ------------
# ----------------------------------------------------------------
cleaned_root = os.path.join(deriv_dir, f"{STIMULUS_LABEL_SAVE_STRING}_cleaned")
all_subs     = sorted(
    d for d in os.listdir(cleaned_root) if d.startswith("sub-")
)
if target_subject:
    if target_subject not in all_subs:
        raise ValueError(f"{target_subject} not found in {cleaned_root}")
    subjects = [target_subject]
else:
    subjects = [s for s in all_subs if s not in exclude_subs]

print("Subjects to process →", ", ".join(subjects))
# Out:
# Subjects to process → sub-002, sub-003, sub-004, sub-005, sub-006, sub-007, sub-008, sub-009, sub-010, sub-011, sub-012, sub-013, sub-014, sub-015, sub-016, sub-017, sub-018, sub-019, sub-020, sub-023, sub-024, sub-025, sub-026, sub-027, sub-028, sub-029, sub-030, sub-031, sub-032, sub-033, sub-034, sub-035, sub-036, sub-037, sub-039, sub-040, sub-041, sub-042, sub-043, sub-044, sub-045, sub-046, sub-047, sub-048, sub-049, sub-050, sub-051, sub-052, sub-053, sub-054, sub-055, sub-057, sub-058, sub-059, sub-060, sub-061, sub-062, sub-063, sub-064, sub-065, sub-066, sub-067, sub-070, sub-071, sub-072, sub-073, sub-074, sub-075, sub-076, sub-077, sub-078, sub-079, sub-080, sub-081, sub-082

# %%
# ──────────────────────────────────────────────────────────────
# 3) FETCH SCHAEFER ATLAS  ─────────────────────────────────────
# ──────────────────────────────────────────────────────────────

# Schaefer parcel/atlas parameters
n_rois = 200
yeo_networks = 17
resolution_mm = 2                   # resolution of your Schaefer atlas (double check!)

schaefer    = datasets.fetch_atlas_schaefer_2018(
                 n_rois=n_rois,
                 yeo_networks=yeo_networks,
                 resolution_mm=resolution_mm
             )
atlas_img   = nib.load(schaefer['maps'])  # default 2mm MNI - but our images 3x3x4 (Pieman and others) OR 2.5^3 (ie., Black and Forgot)

atlas_resampled = resample_to_img(atlas_img, bold_img, interpolation='nearest')
atlas_data     = atlas_resampled.get_fdata()



# Change Schaeffer Labels so 0 is whole brain and 1 corresponds to 1st ROI
labels = schaefer['labels']
# change to string and remove excess
labels = [l.replace(b'17Networks_', b'').decode('utf-8') for l in labels]
# Prepend background label
labels = np.insert(labels, 0, "Background")

# %%
# ──────────────────────────────────────────────────────────────
# 4) Define NNLS function  ─────────────────────────────────────
# ──────────────────────────────────────────────────────────────
def rsa_nnls(neural_rdm: np.ndarray, model_rdm: np.ndarray):
    """
    Non-Negative Least-Squares RSA.
    Returns
    -------
    beta : float   – coefficient for the model RDM (≥ 0) 
    r2   : float   – coefficient of determination for the NNLS fit
    """
    # ----------------------------------------------------------
    # 1) VECTORISE LOWER-TRIANGLE (k = -1 keeps diagonal out)
    # ----------------------------------------------------------
    i_low = np.tril_indices(160, k=-1)
    y = neural_rdm[i_low]                   # dependent variable, shape (N,)
    X = model_rdm[i_low][:, None]           # predictor,      shape (N,1)

    # add a constant column so the fit can pick up any baseline offset;
    # both columns are subject to the non-negativity constraint.
    X = np.column_stack([np.ones_like(y), X])   # shape (N,2)

    # ----------------------------------------------------------
    # 2) NNLS FIT
    # ----------------------------------------------------------
    coef, model_fit = nnls(X, y)            # coef[0] = intercept, coef[1] = beta (≥0)

    # ----------------------------------------------------------
    # 3) GOODNESS-OF-FIT (pseudo-R²)
    # ----------------------------------------------------------
    #y_hat = X @ coef
    #ss_res = np.sum((y - y_hat) ** 2)
    #ss_tot = np.sum((y - y.mean()) ** 2)
    #r2     = 1 - ss_res / ss_tot if ss_tot > 0 else 0.0

    beta = float(coef[1])
    return beta, model_fit

# ──────────────────────────────────────────────────────────────
# 5) Single Trait per-subject function  (adds run-skip check)  ─────────
# ──────────────────────────────────────────────────────────────
def run_parcel_rsa_for_subject(sub: str,
        trait_save: str,
        model_rdm: np.ndarray):
    func_dir   = os.path.join(cleaned_root, sub, "func")
    run_pat    = os.path.join(func_dir,
                  f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_run-*_*cleaned_desc-masked_bold.nii.gz")
    single_pat = os.path.join(func_dir,
                  f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_cleaned_desc-masked_bold.nii.gz")
    bold_files = sorted(glob.glob(run_pat)) + sorted(glob.glob(single_pat))
    if not bold_files:
        print(f"⏩ {sub}: no cleaned runs")
        return

    rows = []
    for bf in bold_files:
        m   = re.search(r"_run-(\d+)_", os.path.basename(bf))
        run = m.group(1) if m else None
        if run and (sub, run) in exclude_sub_runs:
            print(f"   • skipping {sub} run-{run} (in exclusion list)")
            continue

        bold_img  = nib.load(bf)
        bold_data = bold_img.get_fdata()

        atlas_resampled = resample_to_img(atlas_img, bold_img, interpolation="nearest")
        atlas_data      = atlas_resampled.get_fdata()

        for parcel_id in range(1, n_rois + 1):
            mask = atlas_data == parcel_id
            if not mask.any(): continue
            rdm   = 1 - np.corrcoef(bold_data[mask, :].T).astype(np.float32)
            beta, rnorm = rsa_nnls(rdm, model_rdm)  
            parcel_label = labels[parcel_id]
            rows.append([sub, run or "NA", parcel_id, parcel_label, beta, rnorm])
            
    # ---- write one CSV per subject ----
    out_dir  = os.path.join(deriv_dir, "RSA_stats")

    # add the stimulus‐specific subfolder (e.g. "pieman")
    stim_folder = os.path.join(out_dir, STIMULUS_LABEL_SAVE_STRING)
    os.makedirs(stim_folder, exist_ok=True)

    # add the trait‐specific subfolder (e.g. "feeling_Affectionate")
    trait_folder = os.path.join(stim_folder, trait_save)
    os.makedirs(trait_folder, exist_ok=True)

    out_csv = os.path.join(trait_folder, f"{sub}_{STIMULUS_LABEL_SAVE_STRING}_{trait_save}_parcel_RSA_NNLS.csv")
    with open(out_csv, "w", newline="") as f:
        csv.writer(f).writerows([["subject","run","parcel_num","parcel_label","beta","rnorm"]] + rows)
    print(f"✅ {sub}: {len(rows)} rows → {out_csv}")

# %%
# ----------------------------------------------------------------------
# 6. CALL FUNCTION FOR EACH SUBJECT
# ----------------------------------------------------------------------
for trait_label, trait_save in zip(ALL_TRAIT_LABELS, ALL_TRAIT_SAVE_STRS):

    print(f"\n── TRAIT: {trait_label} ──")

    # 1) load that trait's behavioural RDM once
    model_rdm = np.load(
        os.path.join(deriv_dir, "RDMs_behavior",
                     f"{STIMULUS_LABEL_SAVE_STRING}_{trait_save}_RDM.npy")
    )

    # 2) run every subject for this trait
    for sub in subjects:
        run_parcel_rsa_for_subject(sub, trait_save, model_rdm)

        
print("\nALL DONE 🎉")
# Out:
# ── TRAIT: Open-minded ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-002_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-003_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-004_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-005_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-006_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-007_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-008_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-009_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-010_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-011_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-012_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-013_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-014_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-015_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-016_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-017_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-018_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-019_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-020_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-023_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-024_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-025_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-026_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-027_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-028_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-029_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-030_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-031_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-032_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-033_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-034_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-035_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-036_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-037_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-039_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-040_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-041_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-042_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-043_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-044_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-045_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-046_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-047_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-048_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-049_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-050_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-051_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-052_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-053_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-054_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-055_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-057_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-058_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-059_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-060_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-061_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-062_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-063_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-064_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-065_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-066_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-067_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-070_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-071_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-072_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-073_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-074_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-075_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-076_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-077_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-078_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-079_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-080_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-081_pieman_Open_minded_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/sub-082_pieman_Open_minded_parcel_RSA_NNLS.csv
#
# ── TRAIT: feeling Affectionate ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-002_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-003_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-004_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-005_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-006_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-007_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-008_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-009_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-010_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-011_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-012_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-013_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-014_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-015_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-016_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-017_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-018_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-019_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-020_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-023_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-024_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-025_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-026_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-027_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-028_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-029_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-030_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-031_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-032_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-033_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-034_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-035_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-036_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-037_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-039_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-040_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-041_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-042_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-043_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-044_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-045_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-046_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-047_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-048_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-049_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-050_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-051_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-052_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-053_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-054_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-055_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-057_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-058_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-059_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-060_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-061_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-062_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-063_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-064_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-065_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-066_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-067_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-070_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-071_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-072_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-073_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-074_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-075_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-076_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-077_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-078_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-079_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-080_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-081_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/sub-082_pieman_feeling_Affectionate_parcel_RSA_NNLS.csv
#
# ── TRAIT: Attentive ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-002_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-003_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-004_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-005_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-006_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-007_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-008_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-009_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-010_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-011_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-012_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-013_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-014_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-015_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-016_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-017_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-018_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-019_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-020_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-023_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-024_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-025_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-026_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-027_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-028_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-029_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-030_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-031_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-032_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-033_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-034_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-035_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-036_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-037_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-039_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-040_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-041_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-042_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-043_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-044_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-045_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-046_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-047_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-048_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-049_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-050_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-051_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-052_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-053_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-054_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-055_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-057_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-058_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-059_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-060_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-061_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-062_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-063_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-064_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-065_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-066_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-067_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-070_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-071_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-072_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-073_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-074_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-075_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-076_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-077_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-078_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-079_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-080_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-081_pieman_Attentive_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/sub-082_pieman_Attentive_parcel_RSA_NNLS.csv
#
# ── TRAIT: Assertive ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-002_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-003_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-004_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-005_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-006_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-007_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-008_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-009_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-010_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-011_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-012_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-013_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-014_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-015_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-016_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-017_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-018_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-019_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-020_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-023_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-024_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-025_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-026_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-027_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-028_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-029_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-030_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-031_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-032_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-033_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-034_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-035_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-036_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-037_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-039_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-040_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-041_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-042_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-043_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-044_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-045_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-046_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-047_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-048_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-049_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-050_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-051_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-052_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-053_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-054_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-055_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-057_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-058_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-059_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-060_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-061_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-062_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-063_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-064_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-065_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-066_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-067_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-070_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-071_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-072_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-073_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-074_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-075_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-076_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-077_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-078_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-079_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-080_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-081_pieman_Assertive_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/sub-082_pieman_Assertive_parcel_RSA_NNLS.csv
#
# ── TRAIT: feeling Gloomy ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-002_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-003_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-004_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-005_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-006_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-007_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-008_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-009_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-010_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-011_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-012_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-013_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-014_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-015_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-016_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-017_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-018_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-019_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-020_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-023_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-024_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-025_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-026_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-027_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-028_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-029_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-030_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-031_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-032_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-033_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-034_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-035_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-036_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-037_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-039_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-040_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-041_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-042_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-043_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-044_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-045_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/sub-046_pieman_feeling_Gloomy_parcel_RSA_NNLS.csv
# ...
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-044_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-045_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-046_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-047_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-048_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-049_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-050_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-051_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-052_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-053_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-054_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-055_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-057_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-058_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-059_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-060_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-061_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-062_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-063_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-064_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-065_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-066_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-067_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-070_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-071_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-072_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-073_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-074_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-075_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-076_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-077_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-078_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-079_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-080_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-081_pieman_Self_disciplined_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/sub-082_pieman_Self_disciplined_parcel_RSA_NNLS.csv
#
# ── TRAIT: Contemplating ──
# ✅ sub-002: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-002_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-003: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-003_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-004: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-004_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-005: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-005_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-006: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-006_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-007: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-007_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-008: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-008_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-009: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-009_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-010: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-010_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-011: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-011_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-012: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-012_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-013: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-013_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-014: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-014_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-015: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-015_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-016: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-016_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-017: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-017_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-018: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-018_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-019: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-019_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-020: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-020_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-023: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-023_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-024: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-024_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-025: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-025_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-026: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-026_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-027: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-027_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-028: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-028_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-029: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-029_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-030: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-030_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-031: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-031_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-032: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-032_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-033: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-033_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-034: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-034_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-035: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-035_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-036: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-036_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-037: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-037_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-039: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-039_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-040: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-040_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-041: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-041_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-042: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-042_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-043: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-043_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-044: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-044_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-045: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-045_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-046: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-046_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-047: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-047_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-048: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-048_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-049: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-049_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-050: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-050_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-051: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-051_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-052: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-052_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-053: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-053_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-054: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-054_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-055: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-055_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-057: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-057_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-058: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-058_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-059: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-059_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-060: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-060_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-061: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-061_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-062: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-062_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-063: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-063_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-064: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-064_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-065: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-065_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-066: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-066_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-067: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-067_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-070: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-070_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-071: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-071_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-072: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-072_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-073: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-073_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-074: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-074_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-075: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-075_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-076: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-076_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-077: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-077_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-078: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-078_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-079: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-079_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-080: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-080_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-081: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-081_pieman_Contemplating_parcel_RSA_NNLS.csv
# ✅ sub-082: 200 rows → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/sub-082_pieman_Contemplating_parcel_RSA_NNLS.csv
#
# ALL DONE 🎉

# %%
# ------------------------------------------------------------------
# 0) helper: run parcel-wise t-tests for ONE trait and save summary
# ------------------------------------------------------------------
def run_group_stats_for_trait(stim_label: str,
                              trait_save: str,
                              trait_long: str,
                              subjects: list[str],
                              n_rois: int):

    # (1) gather all subject files for this trait
    dfs = []
    for sub in subjects:
        filepath = os.path.join(
            deriv_dir, "RSA_stats", stim_label, trait_save,
            f"{sub}_{stim_label}_{trait_save}_parcel_RSA_NNLS.csv"   
        )
        dfs.append(pd.read_csv(filepath))
    all_df = pd.concat(dfs, ignore_index=True)
    

    # (2) sanity check
    n_sub = all_df["subject"].nunique()
    print(f"{trait_long}: concatenated {n_sub} subjects")

    # (3) parcel-wise one-sample t-tests
    t_vals, p_vals = [], []
    for parcel in range(1, n_rois + 1):
        parcel_df = all_df[all_df["parcel_num"] == parcel]
        assert len(parcel_df) == n_sub, \
            f"Parcel {parcel}: expected {n_sub} rows, got {len(parcel_df)}"
        t, p = ttest_1samp(parcel_df["beta"], 0, alternative="greater")
        t_vals.append(t); p_vals.append(p)

    # (4) summary dataframe
    summary = pd.DataFrame({
        "parcel_num" : np.arange(1, n_rois + 1),
        "parcel_label": labels[1:],       # skip background
        "t_value"    : t_vals,
        "p_value"    : p_vals
    })
    summary = summary.sort_values("parcel_num")      # ← NEW
    summary["parcel_label"] = labels[1:]    # ← NEW
    # (5) save
    out_dir = os.path.join(
        deriv_dir, "RSA_stats", stim_label, trait_save
    )
    os.makedirs(out_dir, exist_ok=True)
    out_csv = os.path.join(
        out_dir, f"group_stats_{stim_label}_{trait_save}_NNLS.csv"
    )
    summary.to_csv(out_csv, index=False)
    print(f"✅ Saved group stats for {trait_long} → {out_csv}\n")

# %%
# ------------------------------------------------------------------
# 1) DRIVER LOOP  (iterate over all 13 traits)
# ------------------------------------------------------------------
for trait_long, trait_save in zip(ALL_TRAIT_LABELS, ALL_TRAIT_SAVE_STRS):
    run_group_stats_for_trait(
        STIMULUS_LABEL_SAVE_STRING,
        trait_save,
        trait_long,
        subjects,
        n_rois
    )
# Out:
# Open-minded: concatenated 75 subjects
# ✅ Saved group stats for Open-minded → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Open_minded/group_stats_pieman_Open_minded_NNLS.csv
#
# feeling Affectionate: concatenated 75 subjects
# ✅ Saved group stats for feeling Affectionate → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Affectionate/group_stats_pieman_feeling_Affectionate_NNLS.csv
#
# Attentive: concatenated 75 subjects
# ✅ Saved group stats for Attentive → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Attentive/group_stats_pieman_Attentive_NNLS.csv
#
# Assertive: concatenated 75 subjects
# ✅ Saved group stats for Assertive → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Assertive/group_stats_pieman_Assertive_NNLS.csv
#
# feeling Gloomy: concatenated 75 subjects
# ✅ Saved group stats for feeling Gloomy → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Gloomy/group_stats_pieman_feeling_Gloomy_NNLS.csv
#
# feeling Peaceful: concatenated 75 subjects
# ✅ Saved group stats for feeling Peaceful → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Peaceful/group_stats_pieman_feeling_Peaceful_NNLS.csv
#
# Agreeable: concatenated 75 subjects
# ✅ Saved group stats for Agreeable → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Agreeable/group_stats_pieman_Agreeable_NNLS.csv
#
# Judging: concatenated 75 subjects
# ✅ Saved group stats for Judging → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Judging/group_stats_pieman_Judging_NNLS.csv
#
# feeling Angry: concatenated 75 subjects
# ✅ Saved group stats for feeling Angry → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Angry/group_stats_pieman_feeling_Angry_NNLS.csv
#
# feeling Bewildered: concatenated 75 subjects
# ✅ Saved group stats for feeling Bewildered → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/feeling_Bewildered/group_stats_pieman_feeling_Bewildered_NNLS.csv
#
# Impulsive: concatenated 75 subjects
# ✅ Saved group stats for Impulsive → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Impulsive/group_stats_pieman_Impulsive_NNLS.csv
#
# Self-disciplined: concatenated 75 subjects
# ✅ Saved group stats for Self-disciplined → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Self_disciplined/group_stats_pieman_Self_disciplined_NNLS.csv
#
# Contemplating: concatenated 75 subjects
# ✅ Saved group stats for Contemplating → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/Contemplating/group_stats_pieman_Contemplating_NNLS.csv

# %% [markdown]
# # Multiple Regression

# %%
def compute_r2(X, y):
    """
    Compute the coefficient of determination (R²) for a linear regression model.
    Parameters
    ----------"""
    betas, _ = nnls(X, y)
    y_pred = X @ betas
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

def permutation_test(X, y, n_permutations=100):

    # compute observed R2
    r2_observed = compute_r2(X, y)
    
    # Permutation test for R² - create null distribution from N permutations
    r2_values = np.zeros(n_permutations)
    for i in range(n_permutations):
        y_permuted = np.random.permutation(y)
        r2_values[i] = compute_r2(X, y_permuted)
    

    # retrurn p-value and pseudo-t value
    pseudo_t = (r2_observed - np.mean(r2_values)) / np.std(r2_values, ddof=1)
    p_value = np.mean(r2_values >= r2_observed)
    return pseudo_t, p_value

# %%
# 1) Define the 13 trait labels and their save-strings
ALL_TRAIT_LABELS = [
    "Open-minded","feeling Affectionate","Attentive","Assertive",
    "feeling Gloomy","feeling Peaceful","Agreeable","Judging",
    "feeling Angry","feeling Bewildered","Impulsive",
    "Self-disciplined","Contemplating"
]

ALL_TRAIT_SAVE_STRS = [t.replace(" ","_").replace("-","_") for t in ALL_TRAIT_LABELS]

# 2) Load all the single-trait .npy RDMs 
model_rdms = {}
for trait, sstr in zip(ALL_TRAIT_LABELS, ALL_TRAIT_SAVE_STRS):
    filepath = os.path.join(
        deriv_dir, "RDMs_behavior",
        f"{STIMULUS_LABEL_SAVE_STRING}_{sstr}_RDM.npy"
    )
    model_rdms[trait] = np.load(filepath)

# 3) multi-regression RSA 
def rsa_multi_nnls(neural_rdm, model_rdms, traits):
    idx = np.tril_indices(neural_rdm.shape[0], k=-1)
    y   = neural_rdm[idx]
    
    # design matrix of all behavioural RDMs
    Xs  = [model_rdms[t][idx] for t in traits]
    X   = np.column_stack(Xs)              # shape (N, p)
    X   = np.column_stack([np.ones_like(y), X])   # prepend intercept

    # NNLS
    coef, rnorm = nnls(X, y)                   
    #coef, _ = nnls(X, y)                   # coef[0] = intercept
    betas = dict(zip(traits, coef[1:]))

    


    # pseudo-r2 for full model vs null (y̅)
    y_pred = X @ coef
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)

    r2 = 1 - (ss_res / ss_tot)

    # compute pseudo F-statistic
    p = len(traits) 
    N = len(y)
    ss_reg = ss_tot - ss_res
    f_stat = (ss_reg / p) / (ss_res / (N - p - 1))


    # permutation test
    pseudo_t, permutation_p_value = permutation_test(X, y)

    return betas, r2, pseudo_t, permutation_p_value, float(f_stat)

# 4) run multi-regression for each subject 
def run_multi_for_subject(sub):
    func_dir   = os.path.join(cleaned_root, sub, "func")
    run_pat    = os.path.join(
        func_dir,
        f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_run-*_*cleaned_desc-masked_bold.nii.gz"
    )
    single_pat = os.path.join(
        func_dir,
        f"{sub}_task-{STIMULUS_LABEL_SAVE_STRING}_cleaned_desc-masked_bold.nii.gz"
    )
    bold_files = sorted(glob.glob(run_pat)) + sorted(glob.glob(single_pat))
    if not bold_files:
        print(f"⏩ {sub}: no runs"); return

    rows = []
    for bf in bold_files:
        m   = re.search(r"_run-(\d+)_", os.path.basename(bf))
        run = m.group(1) if m else "NA"
        if (sub, run) in exclude_sub_runs: continue

        bold_img  = nib.load(bf)
        bold_data = bold_img.get_fdata()
        atlas_res = resample_to_img(atlas_img, bold_img, interpolation="nearest")
        atlas_dat = atlas_res.get_fdata()

        for parcel_id in range(1, n_rois+1):
            print(f"Parcel {parcel_id} of {n_rois}")    
            mask = atlas_dat == parcel_id
            if not mask.any(): continue
            neural_rdm = 1 - np.corrcoef(bold_data[mask,:].T).astype(np.float32)
            betas, r2, pseudo_t, permutation_p_value, f_stat = rsa_multi_nnls(neural_rdm, model_rdms, ALL_TRAIT_LABELS)
            parcel_label = labels[parcel_id]     # ← NEW column
            # build row: sub, run, parcel, β₁…β₁₃, F_stat
            row = [sub, run, parcel_id, parcel_label] + [betas[t] for t in ALL_TRAIT_LABELS] + [r2] + [pseudo_t] + [permutation_p_value]+[float(f_stat)]
            rows.append(row)

    # write out into a new multi_regression folder
    out_base = os.path.join(
        deriv_dir, "RSA_stats",
        STIMULUS_LABEL_SAVE_STRING, "multi_regression"
    )
    os.makedirs(out_base, exist_ok=True)

    header = ["subject","run","parcel_num", "parcel_label"] + ALL_TRAIT_SAVE_STRS + ["r2"] + ["pseudo_t"] + ["permutation_p_value"]+["f_stat"]
    out_csv = os.path.join(
        out_base,
        f"{sub}_{STIMULUS_LABEL_SAVE_STRING}_multi_parcel_RSA_NNLS.csv"
    )
    with open(out_csv, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(header)
        w.writerows(rows)

    print(f"✅ {sub} MULTI-REG CSV → {out_csv}")

# 5) callfor each subject
for sub in subjects:
    run_multi_for_subject(sub)
    # break

print("ALL MULTI-REG DONE 🎉")
# Out:
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-002 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-002_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-003 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-003_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-004 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-004_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-005 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-005_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-006 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-006_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-007 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-007_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-008 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-008_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-009 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-009_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-010 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-010_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-011 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-011_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-012 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-012_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-013 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-013_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-014 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-014_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# ...
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-078 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-078_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-079 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-079_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-080 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-080_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-081 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-081_pieman_multi_parcel_RSA_NNLS.csv
# Parcel 1 of 200
# Parcel 2 of 200
# Parcel 3 of 200
# Parcel 4 of 200
# Parcel 5 of 200
# Parcel 6 of 200
# Parcel 7 of 200
# Parcel 8 of 200
# Parcel 9 of 200
# Parcel 10 of 200
# Parcel 11 of 200
# Parcel 12 of 200
# Parcel 13 of 200
# Parcel 14 of 200
# Parcel 15 of 200
# Parcel 16 of 200
# Parcel 17 of 200
# Parcel 18 of 200
# Parcel 19 of 200
# Parcel 20 of 200
# Parcel 21 of 200
# Parcel 22 of 200
# Parcel 23 of 200
# Parcel 24 of 200
# Parcel 25 of 200
# Parcel 26 of 200
# Parcel 27 of 200
# Parcel 28 of 200
# Parcel 29 of 200
# Parcel 30 of 200
# Parcel 31 of 200
# Parcel 32 of 200
# Parcel 33 of 200
# Parcel 34 of 200
# Parcel 35 of 200
# Parcel 36 of 200
# Parcel 37 of 200
# Parcel 38 of 200
# Parcel 39 of 200
# Parcel 40 of 200
# Parcel 41 of 200
# Parcel 42 of 200
# Parcel 43 of 200
# Parcel 44 of 200
# Parcel 45 of 200
# Parcel 46 of 200
# Parcel 47 of 200
# Parcel 48 of 200
# Parcel 49 of 200
# Parcel 50 of 200
# Parcel 51 of 200
# Parcel 52 of 200
# Parcel 53 of 200
# Parcel 54 of 200
# Parcel 55 of 200
# Parcel 56 of 200
# Parcel 57 of 200
# Parcel 58 of 200
# Parcel 59 of 200
# Parcel 60 of 200
# Parcel 61 of 200
# Parcel 62 of 200
# Parcel 63 of 200
# Parcel 64 of 200
# Parcel 65 of 200
# Parcel 66 of 200
# Parcel 67 of 200
# Parcel 68 of 200
# Parcel 69 of 200
# Parcel 70 of 200
# Parcel 71 of 200
# Parcel 72 of 200
# Parcel 73 of 200
# Parcel 74 of 200
# Parcel 75 of 200
# Parcel 76 of 200
# Parcel 77 of 200
# Parcel 78 of 200
# Parcel 79 of 200
# Parcel 80 of 200
# Parcel 81 of 200
# Parcel 82 of 200
# Parcel 83 of 200
# Parcel 84 of 200
# Parcel 85 of 200
# Parcel 86 of 200
# Parcel 87 of 200
# Parcel 88 of 200
# Parcel 89 of 200
# Parcel 90 of 200
# Parcel 91 of 200
# Parcel 92 of 200
# Parcel 93 of 200
# Parcel 94 of 200
# Parcel 95 of 200
# Parcel 96 of 200
# Parcel 97 of 200
# Parcel 98 of 200
# Parcel 99 of 200
# Parcel 100 of 200
# Parcel 101 of 200
# Parcel 102 of 200
# Parcel 103 of 200
# Parcel 104 of 200
# Parcel 105 of 200
# Parcel 106 of 200
# Parcel 107 of 200
# Parcel 108 of 200
# Parcel 109 of 200
# Parcel 110 of 200
# Parcel 111 of 200
# Parcel 112 of 200
# Parcel 113 of 200
# Parcel 114 of 200
# Parcel 115 of 200
# Parcel 116 of 200
# Parcel 117 of 200
# Parcel 118 of 200
# Parcel 119 of 200
# Parcel 120 of 200
# Parcel 121 of 200
# Parcel 122 of 200
# Parcel 123 of 200
# Parcel 124 of 200
# Parcel 125 of 200
# Parcel 126 of 200
# Parcel 127 of 200
# Parcel 128 of 200
# Parcel 129 of 200
# Parcel 130 of 200
# Parcel 131 of 200
# Parcel 132 of 200
# Parcel 133 of 200
# Parcel 134 of 200
# Parcel 135 of 200
# Parcel 136 of 200
# Parcel 137 of 200
# Parcel 138 of 200
# Parcel 139 of 200
# Parcel 140 of 200
# Parcel 141 of 200
# Parcel 142 of 200
# Parcel 143 of 200
# Parcel 144 of 200
# Parcel 145 of 200
# Parcel 146 of 200
# Parcel 147 of 200
# Parcel 148 of 200
# Parcel 149 of 200
# Parcel 150 of 200
# Parcel 151 of 200
# Parcel 152 of 200
# Parcel 153 of 200
# Parcel 154 of 200
# Parcel 155 of 200
# Parcel 156 of 200
# Parcel 157 of 200
# Parcel 158 of 200
# Parcel 159 of 200
# Parcel 160 of 200
# Parcel 161 of 200
# Parcel 162 of 200
# Parcel 163 of 200
# Parcel 164 of 200
# Parcel 165 of 200
# Parcel 166 of 200
# Parcel 167 of 200
# Parcel 168 of 200
# Parcel 169 of 200
# Parcel 170 of 200
# Parcel 171 of 200
# Parcel 172 of 200
# Parcel 173 of 200
# Parcel 174 of 200
# Parcel 175 of 200
# Parcel 176 of 200
# Parcel 177 of 200
# Parcel 178 of 200
# Parcel 179 of 200
# Parcel 180 of 200
# Parcel 181 of 200
# Parcel 182 of 200
# Parcel 183 of 200
# Parcel 184 of 200
# Parcel 185 of 200
# Parcel 186 of 200
# Parcel 187 of 200
# Parcel 188 of 200
# Parcel 189 of 200
# Parcel 190 of 200
# Parcel 191 of 200
# Parcel 192 of 200
# Parcel 193 of 200
# Parcel 194 of 200
# Parcel 195 of 200
# Parcel 196 of 200
# Parcel 197 of 200
# Parcel 198 of 200
# Parcel 199 of 200
# Parcel 200 of 200
# ✅ sub-082 MULTI-REG CSV → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/sub-082_pieman_multi_parcel_RSA_NNLS.csv
# ALL MULTI-REG DONE 🎉

# %%
# collect all R2_stats
records = []
pattern = os.path.join(
    deriv_dir, "RSA_stats", STIMULUS_LABEL_SAVE_STRING,
    "multi_regression", "*_multi_parcel_RSA_NNLS.csv"
)
for fn in glob.glob(pattern):
    df = pd.read_csv(fn, usecols=["subject","run","parcel_num","r2"])
    # create one row per entry
    df["unit"] = df["subject"] + "_" + df["run"].astype(str)
    records.append(df)
all_f = pd.concat(records, ignore_index=True)

# group‐level t-test per parcel
group_results = []
for parcel, grp in all_f.groupby("parcel_num"):
    t_stat, p_unc = ttest_1samp(grp["r2"], popmean=0, alternative="greater")
    group_results.append((parcel, t_stat, p_unc))

gr = pd.DataFrame(group_results, columns=["parcel_num","t_stat","p_uncorrected"])
# FDR across all parcels
_, p_fdr = fdrcorrection(gr["p_uncorrected"])
gr["p_fdr"] = p_fdr

# add parcel labels
gr["parcel_label"] = labels[1:]  # skip background label

# reorganize columns
gr = gr[["parcel_num","parcel_label","t_stat","p_uncorrected","p_fdr"]]

# save
out_group = os.path.join(
    deriv_dir, "RSA_stats", STIMULUS_LABEL_SAVE_STRING,
    "multi_regression", "group_R2_stats_with_FDR_NNLS.csv"
)
gr.to_csv(out_group, index=False)
print(f"✅ Saved group‐level R2‐test results → {out_group}")
# Out:
# ✅ Saved group‐level R2‐test results → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/group_R2_stats_with_FDR_NNLS.csv

# %%
# collect all F_stats
records = []
pattern = os.path.join(
    deriv_dir, "RSA_stats", STIMULUS_LABEL_SAVE_STRING,
    "multi_regression", "*_multi_parcel_RSA_NNLS.csv"
)
for fn in glob.glob(pattern):
    df = pd.read_csv(fn, usecols=["subject","run","parcel_num","f_stat"])
    # create one row per entry
    df["unit"] = df["subject"] + "_" + df["run"].astype(str)
    records.append(df)
all_f = pd.concat(records, ignore_index=True)

# group‐level t-test per parcel
group_results = []
for parcel, grp in all_f.groupby("parcel_num"):
    t_stat, p_unc = ttest_1samp(grp["f_stat"], popmean=1, alternative="greater")
    group_results.append((parcel, t_stat, p_unc))

gr = pd.DataFrame(group_results, columns=["parcel_num","t_stat","p_uncorrected"])
# FDR across all parcels
_, p_fdr = fdrcorrection(gr["p_uncorrected"])
gr["p_fdr"] = p_fdr

# add parcel labels
gr["parcel_label"] = labels[1:]  # skip background label

# reorganize columns
gr = gr[["parcel_num","parcel_label","t_stat","p_uncorrected","p_fdr"]]

# save
out_group = os.path.join(
    deriv_dir, "RSA_stats", STIMULUS_LABEL_SAVE_STRING,
    "multi_regression", "group_F1_stats_with_FDR_NNLS.csv"
)
gr.to_csv(out_group, index=False)
print(f"✅ Saved group‐level F‐test results → {out_group}")
# Out:
# ✅ Saved group‐level F‐test results → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/group_F1_stats_with_FDR_NNLS.csv

# %%
# ─── PARAMETERS ───────────────────────────────────────────────────────────
n_rois = 200
yeo_networks = 17
resolution_mm = 2
# fdr_alpha = 0.05     # threshold for p_fdr

# input CSV from group‐level t-test against F=1
group_csv = "/Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/group_F1_stats_with_FDR_NNLS.csv"

# output map filename
out_nii  = f"{n_rois}_parcel_t_map_NNLS.nii.gz"

# ─── 1) LOAD & THRESHOLD ─────────────────────────────────────────────────
gr = pd.read_csv(group_csv)
# grab the full list of t‐stats in parcel order
t_values = gr.sort_values("parcel_num")["t_stat"].tolist()
# threshold down to only the significant parcels
# thr = gr[gr["p_fdr"] < fdr_alpha]

# ─── 2) FETCH THE SCHAEFER ATLAS ─────────────────────────────────────
schaefer   = datasets.fetch_atlas_schaefer_2018(
    n_rois=n_rois,
    yeo_networks=yeo_networks,
    resolution_mm=resolution_mm
)
atlas_img  = nib.load(schaefer["maps"])
atlas_data = atlas_img.get_fdata().astype(int)

# sanity check
assert atlas_data.max() == n_rois

# ─── 3) BUILD THE 3D T-STAT MAP ──────────────────────────────────────────
t_map = np.zeros_like(atlas_data, dtype=float)
for _, row in gr.iterrows():
    pid    = int(row["parcel_num"])
    tstat  = float(row["t_stat"])
    t_map[atlas_data == pid] = tstat

# ─── 4) SAVE OUT NIfTI ───────────────────────────────────────────────────
out_dir = os.path.join(
    deriv_dir,
    "RSA_stats",
    STIMULUS_LABEL_SAVE_STRING,   # no {…}
    "multi_regression",           # no {…}
)
os.makedirs(out_dir, exist_ok=True)

out_nii = os.path.join(
    out_dir,
    f"{n_rois}parcel_t_map_NNLS.nii.gz"
)
new_img = nib.Nifti1Image(t_map, atlas_img.affine, atlas_img.header)
nib.save(new_img, out_nii)
print("✅ Saved thresholded t-map →", out_nii)

# ─── 5) PLOT (GLASS BRAIN) ────────────────────────────────────────────────
plotting.plot_glass_brain(
    out_nii,
    # threshold =5.0,      # set t threshold for more or less conservative display
    cmap="magma",
    colorbar=True,
    title=f"Schaefer- {n_rois} parcel t-map NNLS)"
)
plotting.show()
# Out:
# ✅ Saved thresholded t-map → /Volumes/Passport/fmriprep/derivatives/RSA_stats/pieman/multi_regression/200parcel_t_map_NNLS.nii.gz

# %%
import nibabel as nib
import numpy as np
from nilearn.image import resample_to_img

# atlases you already loaded
atlas_res = resample_to_img(atlas_img, bold_img, interpolation="nearest")
atlas_data = atlas_res.get_fdata()

parcel_id = 173            # pick any ID you want to sanity-check
mask      = (atlas_data == parcel_id).astype(np.uint8)

mask_img = nib.Nifti1Image(mask, atlas_res.affine, atlas_res.header)
nib.save(mask_img, f"parcel_{parcel_id}_mask.nii.gz")
print("mask saved → parcel_173_mask.nii.gz")
# Out:
# mask saved → parcel_173_mask.nii.gz
